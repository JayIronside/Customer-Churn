# %% [markdown]
# # Importing data for use

# %%
import pandas as pd

# %%
data = pd.read_csv('Customer-churn.csv')

# %%
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Feature Selection

# %%
feature = data[['gender', 'PhoneService', 'PaperlessBilling', 'StreamingTV', 'MonthlyCharges', 'TotalCharges' ]]

# %%
feature
# Out:
#       gender PhoneService PaperlessBilling StreamingTV  MonthlyCharges  \
# 0     Female           No              Yes          No           29.85
# 1       Male          Yes               No          No           56.95
# 2       Male          Yes              Yes          No           53.85
# 3       Male           No               No          No           42.30
# 4     Female          Yes              Yes          No           70.70
# ...      ...          ...              ...         ...             ...
# 7038    Male          Yes              Yes         Yes           84.80
# 7039  Female          Yes              Yes         Yes          103.20
# 7040  Female           No              Yes          No           29.60
# 7041    Male          Yes              Yes          No           74.40
# 7042    Male          Yes              Yes         Yes          105.65
#
#      TotalCharges
# 0           29.85
# 1          1889.5
# 2          108.15
# 3         1840.75
# ...

# %%
target = data[['Churn']]

# %%
target
# Out:
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 1 columns]

# %% [markdown]
# # Categorical values to Numerical values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
feature["gender"] = le.fit_transform(feature["gender"])
# Out:
# <ipython-input-16-bbded0508cbc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature["gender"] = le.fit_transform(feature["gender"])

# %%
feature['PhoneService'] = le.fit_transform(feature['PhoneService'])
# Out:
# <ipython-input-17-c231c24c46ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature['PhoneService'] = le.fit_transform(feature['PhoneService'])

# %%
feature['PaperlessBilling'] = le.fit_transform(feature['PaperlessBilling'])
# Out:
# <ipython-input-18-79367b6e7f73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature['PaperlessBilling'] = le.fit_transform(feature['PaperlessBilling'])

# %%
feature['StreamingTV'] = le.fit_transform(feature['StreamingTV'])
# Out:
# <ipython-input-19-9b91d1ef2362>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature['StreamingTV'] = le.fit_transform(feature['StreamingTV'])

# %%
feature
# Out:
#       gender  PhoneService  PaperlessBilling  StreamingTV  MonthlyCharges  \
# 0          0             0                 1            0           29.85
# 1          1             1                 0            0           56.95
# 2          1             1                 1            0           53.85
# 3          1             0                 0            0           42.30
# 4          0             1                 1            0           70.70
# ...      ...           ...               ...          ...             ...
# 7038       1             1                 1            2           84.80
# 7039       0             1                 1            2          103.20
# 7040       0             0                 1            0           29.60
# 7041       1             1                 1            0           74.40
# 7042       1             1                 1            2          105.65
#
#      TotalCharges
# 0           29.85
# 1          1889.5
# 2          108.15
# ...

# %%
target = le.fit_transform(data['Churn'])

# %%
target
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %% [markdown]
# # Splitting data for training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
feature_train, feature_test, target_train, target_test = train_test_split(feature, target, test_size = 0.3)

# %%
feature_train
# Out:
#       gender  PhoneService  PaperlessBilling  StreamingTV  MonthlyCharges  \
# 4453       1             1                 1            2           98.50
# 6679       0             0                 0            0           37.70
# 359        1             1                 0            2           97.10
# 6285       1             0                 0            2           54.55
# 902        1             1                 0            2           93.85
# ...      ...           ...               ...          ...             ...
# 4552       0             1                 1            1           20.45
# 3433       1             1                 1            2          107.75
# 4554       1             1                 1            2          108.20
# 349        0             1                 0            0           97.00
# 1682       1             1                 1            2           85.25
#
#      TotalCharges
# 4453      1037.75
# 6679       2288.7
# 359       4016.75
# ...

# %%
target_train
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
feature_train["TotalCharges"] = le.fit_transform(feature_train["TotalCharges"])
# Out:
# <ipython-input-27-f9f6994c0ac2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_train["TotalCharges"] = le.fit_transform(feature_train["TotalCharges"])

# %%
feature_train
# Out:
#       gender  PhoneService  PaperlessBilling  StreamingTV  MonthlyCharges  \
# 4453       1             1                 1            2           98.50
# 6679       0             0                 0            0           37.70
# 359        1             1                 0            2           97.10
# 6285       1             0                 0            2           54.55
# 902        1             1                 0            2           93.85
# ...      ...           ...               ...          ...             ...
# 4552       0             1                 1            1           20.45
# 3433       1             1                 1            2          107.75
# 4554       1             1                 1            2          108.20
# 349        0             1                 0            0           97.00
# 1682       1             1                 1            2           85.25
#
#       TotalCharges
# 4453            52
# 6679          1374
# ...

# %%
feature_test["TotalCharges"] = le.fit_transform(feature_test["TotalCharges"])
# Out:
# <ipython-input-29-22521fca43ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_test["TotalCharges"] = le.fit_transform(feature_test["TotalCharges"])

# %% [markdown]
# # Building the model

# %%
from sklearn.svm import SVC
classifier = SVC()
model = classifier.fit(feature_train, target_train)
prediction = model.predict(feature_test)

# %%
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
dictionary = {"Actual Value": target_test, "Predictions": prediction}
dictionary
# Out:
# {'Actual Value': array([0, 1, 0, ..., 1, 1, 0]),
#  'Predictions': array([0, 0, 0, ..., 0, 0, 0])}

# %%
# Displaying the dictionary as a table
GraphicalRep = pd.DataFrame(dictionary)

# %%
GraphicalRep.tail(30)
# Out:
#       Actual Value  Predictions
# 2083             0            0
# 2084             0            0
# 2085             0            0
# 2086             0            0
# 2087             1            0
# 2088             0            0
# 2089             1            0
# 2090             0            0
# 2091             0            0
# 2092             0            0
# 2093             0            0
# 2094             0            0
# 2095             1            0
# 2096             0            0
# 2097             0            0
# 2098             1            0
# 2099             1            0
# 2100             0            0
# 2101             0            0
# 2102             0            0
# 2103             0            0
# 2104             0            0
# 2105             0            0
# 2106             1            0
# 2107             0            0
# 2108             0            0
# 2109             0            0
# 2110             1            0
# ...

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.metrics import accuracy_score
accuracy_score(target_test, prediction)
# Out:
# 0.7259820160908661

# %%
# using confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(target_test, prediction))
# Out:
# [[1534    0]
#  [ 579    0]]
